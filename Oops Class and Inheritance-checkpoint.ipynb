# %%
# Base class: Vehicle
class Vehicle:
    def __init__(self, make, model):
        self.make = make
        self.model = model

# Subclass: Car (inherits from Vehicle)
class Car(Vehicle):
    def __init__(self, make, model, num_doors):
        # Initialize base class attributes
        super().__init__(make, model)
        self.num_doors = num_doors

    # Method to display all attributes
    def display_info(self):
        print(f"Make: {self.make}")
        print(f"Model: {self.model}")
        print(f"Number of Doors: {self.num_doors}")

car1 = Car("Toyota", "Wokinowa", 4)
car1.display_info()
# Out:
# Make: Toyota
# Model: Wokinowa
# Number of Doors: 4

# %%
Synopsis

Object-Oriented Programming – Class and Inheritance

Objective:
To demonstrate the use of object-oriented programming concepts in Python by creating a base class and a subclass that inherits properties and methods.

Description:
This program illustrates class creation, inheritance, and method overriding in Python.
A base class Vehicle is defined with common attributes make and model.
A subclass Car inherits from Vehicle and introduces an additional attribute num_doors.
The subclass also defines a method display_info() that prints all attributes, showing the concept of reusability through inheritance.

Algorithm Steps:

Start the program.

Define a base class Vehicle with attributes make and model.

Create a subclass Car that inherits from Vehicle.

Add a new attribute num_doors to the Car class.

Use super().__init__() to call the constructor of the base class.

Define a method display_info() in the subclass to print all attributes.

Create an object of the Car class and call display_info().

End the program.
