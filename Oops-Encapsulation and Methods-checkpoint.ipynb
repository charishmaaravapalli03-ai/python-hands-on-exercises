# %%
# Class demonstrating encapsulation
class BankAccount:
    def __init__(self, initial_balance=0):
        # Private attribute
        self.__balance = initial_balance

    # Deposit Method
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ₹{amount}")
        else:
            print("Deposit amount must be positive!")

    # Withdrawal Method
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ₹{amount}")
        elif amount > self.__balance:
            print("Insufficient balance! Withdrawal denied.")
        else:
            print("Invalid withdrawal amount!")

    # Balance Enquiry Method
    def check_balance(self):
        print(f"Current Balance: ₹{self.__balance}")

account = BankAccount(5000)
account.check_balance()

account.deposit(2000)
account.withdraw(1500)
account.withdraw(6000)
account.check_balance()
# Out:
# Current Balance: ₹5000
# Deposited: ₹2000
# Withdrew: ₹1500
# Insufficient balance! Withdrawal denied.
# Current Balance: ₹5500

# %%
Synopsis

OOP – Encapsulation and Methods in a BankAccount Class

Objective:
To implement encapsulation in Python using a class that securely manages account balance with deposit, withdrawal, and balance enquiry methods.

Description:
This exercise demonstrates the principle of encapsulation in object-oriented programming.
A class BankAccount is defined with a private attribute __balance that cannot be accessed directly from outside the class.

Methods are provided to safely modify and access this private data:

deposit() to add funds,

withdraw() to remove funds (ensuring balance never goes negative),

check_balance() to display the current account balance.


Algorithm Steps:
    
Start the program.

Define a class BankAccount with a private attribute __balance.

Initialize the account balance through the constructor.

Define a deposit() method to add money if the amount is positive.

Define a withdraw() method that checks if sufficient funds exist before deduction.

Define a check_balance() method to display the current balance.

Create an object of BankAccount and test all three methods.

End the program.
